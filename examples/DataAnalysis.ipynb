# %% [markdown]
# # Data analysis

# %%
import pandas as pd

# %%
data = pd.read_csv("feature-tables/train-data_1525970319.csv")

data.describe()
# Out:
#          Unnamed: 0     perimeter          area   circularity             ac  \
# count  18927.000000  18927.000000  1.892700e+04  18927.000000   18927.000000
# mean    9463.000000    422.876682  9.214317e+03      2.366939    2182.313809
# std     5463.898608    925.032824  5.362245e+04      2.786500   10951.012989
# min        0.000000     99.071068  6.285000e+02      1.143769       4.105746
# 25%     4731.500000    124.242641  9.170000e+02      1.308409     663.266132
# 50%     9463.000000    175.656854  1.539000e+03      1.539966     954.939171
# 75%    14194.500000    325.941125  3.728750e+03      2.352563    1616.997960
# max    18926.000000  21135.787131  4.221668e+06    199.598296  735442.086714
#
#        mean_intensity  standard_deviation    smoothness      skewness  \
# count    18927.000000        18927.000000  1.892700e+04  1.892700e+04
# mean     32874.188187        18911.135277  1.000000e+00 -7.485518e+08
# std        589.359851          218.777767  6.490256e-11  2.449348e+11
# min      30065.184699        17740.155334  1.000000e+00 -1.126087e+12
# 25%      32538.960885        18793.676909  1.000000e+00 -1.348299e+11
# 50%      32878.485439        18914.626233  1.000000e+00  6.456252e+07
# 75%      33222.841547        19030.976994  1.000000e+00  1.317571e+11
# max      35216.653194        19990.331635  1.000000e+00  1.078932e+12
#
#            class_id
# count  18927.000000
# mean      -0.987848
# std        0.155427
# min       -1.000000
# 25%       -1.000000
# 50%       -1.000000
# 75%       -1.000000
# max        1.000000

# %%
# data division into masses and not masses
data_masses = data[data["class_id"] == 1]

data_fp = data[data["class_id"] == -1]

print(f"Found {len(data_masses)} masses")
print(f"Found {len(data_fp)} false positives")
print(f"{round(100*len(data_masses)/len(data), 1)}% of the whole data is masses.")
# Out:
# Found 115 masses
# Found 18812 false positives
# 0.6% of the whole data is masses.

# %% [markdown]
# ## Mass analysis

# %%
data_masses.describe()
# Out:
#          Unnamed: 0    perimeter           area  circularity             ac  \
# count    115.000000   115.000000     115.000000   115.000000     115.000000
# mean    8968.869565  1312.902864   97842.247826     2.218914   61345.539392
# std     5682.662039   782.190735  125790.284042     1.342837   92737.810994
# min      123.000000   216.468036    2995.500000     1.144189    2058.808089
# 25%     3533.500000   683.691949   17568.500000     1.333955    8263.787815
# 50%     9194.000000  1104.447825   43880.500000     1.681505   23400.953663
# 75%    13558.500000  1831.134723  123813.500000     2.674067   62716.038080
# max    18497.000000  3855.347656  750937.000000     8.698480  545909.698228
#
#        mean_intensity  standard_deviation    smoothness      skewness  \
# count      115.000000          115.000000  1.150000e+02  1.150000e+02
# mean     32786.374028        18917.725836  1.000000e+00 -1.425374e+10
# std        179.465765           48.607447  1.434661e-11  6.038612e+10
# min      32071.475888        18799.189525  1.000000e+00 -2.847217e+11
# 25%      32708.475628        18890.452729  1.000000e+00 -3.907602e+10
# 50%      32764.037764        18918.433613  1.000000e+00 -1.091931e+10
# 75%      32855.378637        18940.840980  1.000000e+00  1.470103e+10
# max      33258.962837        19101.980863  1.000000e+00  1.977431e+11
#
#        class_id
# count     115.0
# mean        1.0
# std         0.0
# min         1.0
# 25%         1.0
# 50%         1.0
# 75%         1.0
# max         1.0

# %%
data_masses[data_masses.area < 2500].count()
# Out:
# Unnamed: 0            0
# perimeter             0
# area                  0
# circularity           0
# ac                    0
# mean_intensity        0
# standard_deviation    0
# smoothness            0
# skewness              0
# class_id              0
# dtype: int64

# %%
from math import sqrt

print(f"Maximum square size for rejection {int(sqrt(2995.500000))}")
# Out:
# Maximum square size for rejection 54

# %% [markdown]
# ## False positive analysis

# %%
data_fp.describe()
# Out:
#          Unnamed: 0     perimeter          area   circularity             ac  \
# count  18812.000000  18812.000000  1.881200e+04  18812.000000   18812.000000
# mean    9466.020678    417.435845  8.672524e+03      2.367844    1820.641954
# std     5462.553935    923.220855  5.242841e+04      2.793025    6856.234007
# min        0.000000     99.071068  6.285000e+02      1.143769       4.105746
# 25%     4740.750000    124.000000  9.150000e+02      1.308363     661.929681
# 50%     9465.500000    174.899495  1.528500e+03      1.538962     950.332202
# 75%    14198.250000    321.324116  3.647500e+03      2.350960    1598.171108
# max    18926.000000  21135.787131  4.221668e+06    199.598296  735442.086714
#
#        mean_intensity  standard_deviation    smoothness      skewness  \
# count    18812.000000        18812.000000  1.881200e+04  1.881200e+04
# mean     32874.725005        18911.094988  1.000000e+00 -6.659930e+08
# std        590.953372          219.412256  6.509064e-11  2.456351e+11
# min      30065.184699        17740.155334  1.000000e+00 -1.126087e+12
# 25%      32536.927413        18792.378727  1.000000e+00 -1.357073e+11
# 50%      32880.247032        18914.421929  1.000000e+00  1.793889e+08
# 75%      33225.887711        19032.157112  1.000000e+00  1.325780e+11
# max      35216.653194        19990.331635  1.000000e+00  1.078932e+12
#
#        class_id
# count   18812.0
# mean       -1.0
# std         0.0
# min        -1.0
# 25%        -1.0
# 50%        -1.0
# 75%        -1.0
# max        -1.0

# %%
small_fp = data_fp[data_fp.area > 2900]

small_fp.describe()
# Out:
#          Unnamed: 0     perimeter          area  circularity             ac  \
# count   5627.000000   5627.000000  5.627000e+03  5627.000000    5627.000000
# mean    9625.068598   1032.405177  2.597724e+04     4.297443    4136.463668
# std     5449.405897   1517.934033  9.360823e+04     3.651267   12219.724110
# min        0.000000    218.485281  2.901500e+03     1.291593     347.918437
# 25%     4890.500000    352.719299  4.136250e+03     2.282492    1684.091954
# 50%     9680.000000    508.384776  6.709500e+03     3.058213    2296.751754
# 75%    14353.500000    953.488851  1.584350e+04     4.674896    3758.862675
# max    18904.000000  21135.787131  4.221668e+06    36.685253  735442.086714
#
#        mean_intensity  standard_deviation    smoothness      skewness  \
# count     5627.000000         5627.000000  5.627000e+03  5.627000e+03
# mean     32873.461767        18915.927746  1.000000e+00 -2.172929e+09
# std        341.668657          102.605282  3.034415e-11  1.184186e+11
# min      31346.000000        18481.880020  1.000000e+00 -6.324181e+11
# 25%      32675.943842        18860.251649  1.000000e+00 -6.607118e+10
# 50%      32870.316239        18915.360127  1.000000e+00  9.400493e+08
# 75%      33081.393156        18972.483644  1.000000e+00  6.259115e+10
# max      34612.210145        19336.674066  1.000000e+00  5.557838e+11
#
#        class_id
# count    5627.0
# mean       -1.0
# std         0.0
# min        -1.0
# 25%        -1.0
# 50%        -1.0
# 75%        -1.0
# max        -1.0

# %%
print(f"Found {len(data_masses)} masses")
print(f"Found {len(small_fp)} false positives")
print(f"{round(100*len(data_masses)/(len(small_fp) + len(data_masses)), 1)}% of the whole data is masses.")
# Out:
# Found 115 masses
# Found 5627 false positives
# 2.0% of the whole data is masses.
