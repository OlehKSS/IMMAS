# %% [markdown]
# # Data analysis

# %%
import pandas as pd

# %%
# For this file we used Dice threshold 0.2, and the min area of a region of interest is 625
#data = pd.read_csv("feature-tables/train-data_1526149385.csv")

# For this file we used Dice threshold 0.2, and the min area of a region of interest is 2500
#data = pd.read_csv("feature-tables/train-data_1526205815.csv")
data = pd.read_csv("feature-tables/train-data_1526398314.csv")

data.describe()
# Out:
#         Unnamed: 0     perimeter          area  circularity            ac  \
# count  5783.000000   5783.000000  5.783000e+03  5783.000000  5.783000e+03
# mean   2891.000000   1351.259527  6.462075e+04     3.964600  1.066692e+04
# std    1669.552635   2581.528906  2.661582e+05     3.975785  6.559408e+04
# min       0.000000    201.254833  2.501000e+03     1.133141  4.554010e+02
# 25%    1445.500000    315.012193  3.790750e+03     1.969335  1.834582e+03
# 50%    2891.000000    472.166520  6.783000e+03     2.644600  2.618461e+03
# 75%    4336.500000   1007.300033  1.935200e+04     4.136451  4.943933e+03
# max    5782.000000  31466.324805  4.814334e+06    56.633370  3.086666e+06
#
#        mean_intensity  standard_deviation    smoothness      skewness  \
# count     5783.000000         5783.000000  5.783000e+03  5.783000e+03
# mean     32740.571206        18918.576672  1.000000e+00  2.125203e+07
# std        373.296758          107.041355  3.164537e-11  1.243748e+11
# min      30887.423873        18315.526662  1.000000e+00 -6.084929e+11
# 25%      32519.449994        18863.437292  1.000000e+00 -6.511659e+10
# 50%      32759.363499        18919.925336  1.000000e+00  8.054992e+08
# 75%      32961.530890        18974.846458  1.000000e+00  6.525449e+10
# max      34484.558125        19455.624403  1.000000e+00  6.646144e+11
#
#        correlation     contrast   uniformity  homogeneity       energy  \
# count  5783.000000  5783.000000  5783.000000  5783.000000  5783.000000
# mean      0.518307   405.146783     0.197019     0.449584     0.417144
# std       0.100225   105.984238     0.133680     0.143436     0.151704
# min       0.106935    68.602843     0.002550     0.102046     0.050501
# 25%       0.455850   329.377089     0.090704     0.340519     0.301171
# 50%       0.533950   408.905388     0.168390     0.443524     0.410353
# 75%       0.593698   485.273956     0.275507     0.551463     0.524887
# max       0.713186   671.470588     0.812420     0.906847     0.901343
#
#        dissimilarity     class_id
# count    5783.000000  5783.000000
# mean       12.545882    -0.971295
# std         3.275104     0.237898
# min         2.123565    -1.000000
# 25%        10.205111    -1.000000
# 50%        12.672170    -1.000000
# 75%        15.012221    -1.000000
# max        20.527574     1.000000

# %%
# data division into masses and not masses
data_masses = data[data["class_id"] == 1]

data_fp = data[data["class_id"] == -1]

print(f"Found {len(data_masses)} masses")
print(f"Found {len(data_fp)} false positives")
print(f"{round(100*len(data_masses)/len(data), 1)}% of the whole data is masses.")
# Out:
# Found 83 masses
# Found 5700 false positives
# 1.4% of the whole data is masses.

# %% [markdown]
# ## Mass analysis

# %%
data_masses.describe()
# Out:
#         Unnamed: 0     perimeter          area  circularity             ac  \
# count    83.000000     83.000000  8.300000e+01    83.000000      83.000000
# mean   2804.108434   3327.702100  2.130053e+05     5.373440   41979.935913
# std    1578.282634   3255.242316  2.930447e+05     5.361562   53501.579097
# min      61.000000    345.639609  5.938000e+03     1.486978    3458.601516
# 25%    1542.500000    946.743684  2.779925e+04     2.144430    9270.942709
# 50%    2752.000000   1935.144222  1.118730e+05     3.389561   17911.232818
# 75%    4271.000000   4904.533172  2.617190e+05     6.453422   51793.909873
# max    5762.000000  14859.172231  1.432510e+06    31.559202  277246.235840
#
#        mean_intensity  standard_deviation    smoothness      skewness  \
# count       83.000000           83.000000  8.300000e+01  8.300000e+01
# mean     32779.884019        18923.212832  1.000000e+00 -6.325640e+09
# std        157.897376           41.484521  1.223552e-11  4.427153e+10
# min      32367.325736        18816.810171  1.000000e+00 -1.389317e+11
# 25%      32714.749126        18908.015618  1.000000e+00 -2.409922e+10
# 50%      32785.167929        18921.971491  1.000000e+00 -2.629802e+09
# 75%      32854.647245        18940.167131  1.000000e+00  1.073179e+10
# max      33249.861114        19083.093768  1.000000e+00  1.740092e+11
#
#        correlation    contrast  uniformity  homogeneity     energy  \
# count    83.000000   83.000000   83.000000    83.000000  83.000000
# mean      0.544663  385.282924    0.210744     0.471139   0.439990
# std       0.071082   90.427109    0.128554     0.124162   0.131764
# min       0.418694  137.714546    0.063343     0.296018   0.251681
# 25%       0.482838  320.654199    0.108665     0.365896   0.329596
# 50%       0.548115  393.755903    0.179784     0.456495   0.424010
# 75%       0.604035  462.137757    0.284760     0.560344   0.533597
# max       0.694991  513.409382    0.640058     0.811156   0.800036
#
#        dissimilarity  class_id
# count      83.000000      83.0
# mean       11.990511       1.0
# std         2.818443       0.0
# min         4.283745       1.0
# 25%         9.981671       1.0
# 50%        12.287024       1.0
# 75%        14.383982       1.0
# max        15.938444       1.0

# %%
data_masses[data_masses.area < 2500].count()
# Out:
# Unnamed: 0            0
# perimeter             0
# area                  0
# circularity           0
# ac                    0
# mean_intensity        0
# standard_deviation    0
# smoothness            0
# skewness              0
# correlation           0
# contrast              0
# uniformity            0
# homogeneity           0
# energy                0
# dissimilarity         0
# class_id              0
# dtype: int64

# %%
from math import sqrt

print(f"Maximum square size for rejection {int(sqrt(data_masses.area.min()))}")
# Out:
# Maximum square size for rejection 77

# %% [markdown]
# ## False positive analysis

# %%
data_fp.describe()
# Out:
#         Unnamed: 0     perimeter          area  circularity            ac  \
# count  5700.000000   5700.000000  5.700000e+03  5700.000000  5.700000e+03
# mean   2892.265263   1322.479749  6.246006e+04     3.944086  1.021095e+04
# std    1670.942465   2559.523564  2.651622e+05     3.948941  6.564733e+04
# min       0.000000    201.254833  2.501000e+03     1.133141  4.554010e+02
# 25%    1443.750000    313.597979  3.765875e+03     1.967126  1.821084e+03
# 50%    2894.500000    467.234018  6.658000e+03     2.639944  2.583347e+03
# 75%    4337.250000    980.647490  1.822638e+04     4.113016  4.762582e+03
# max    5782.000000  31466.324805  4.814334e+06    56.633370  3.086666e+06
#
#        mean_intensity  standard_deviation    smoothness      skewness  \
# count     5700.000000         5700.000000  5.700000e+03  5.700000e+03
# mean     32739.998756        18918.509163  1.000000e+00  1.136717e+08
# std        375.497536          107.701642  3.184057e-11  1.251622e+11
# min      30887.423873        18315.526662  1.000000e+00 -6.084929e+11
# 25%      32514.118976        18862.527581  1.000000e+00 -6.592992e+10
# 50%      32758.830631        18919.898278  1.000000e+00  8.976394e+08
# 75%      32963.472880        18975.360082  1.000000e+00  6.626634e+10
# max      34484.558125        19455.624403  1.000000e+00  6.646144e+11
#
#        correlation     contrast   uniformity  homogeneity       energy  \
# count  5700.000000  5700.000000  5700.000000  5700.000000  5700.000000
# mean      0.517923   405.436029     0.196819     0.449270     0.416811
# std       0.100541   106.173278     0.133754     0.143683     0.151960
# min       0.106935    68.602843     0.002550     0.102046     0.050501
# 25%       0.455528   329.482815     0.090453     0.340036     0.300753
# 50%       0.533856   408.948900     0.168198     0.443435     0.410120
# 75%       0.593590   485.913618     0.275302     0.551377     0.524692
# max       0.713186   671.470588     0.812420     0.906847     0.901343
#
#        dissimilarity  class_id
# count    5700.000000    5700.0
# mean       12.553969      -1.0
# std         3.280804       0.0
# min         2.123565      -1.0
# 25%        10.212198      -1.0
# 50%        12.678182      -1.0
# 75%        15.056238      -1.0
# max        20.527574      -1.0

# %%
small_fp = data_fp[data_fp.area > 2500]

small_fp.describe()
# Out:
#         Unnamed: 0     perimeter          area  circularity            ac  \
# count  5700.000000   5700.000000  5.700000e+03  5700.000000  5.700000e+03
# mean   2892.265263   1322.479749  6.246006e+04     3.944086  1.021095e+04
# std    1670.942465   2559.523564  2.651622e+05     3.948941  6.564733e+04
# min       0.000000    201.254833  2.501000e+03     1.133141  4.554010e+02
# 25%    1443.750000    313.597979  3.765875e+03     1.967126  1.821084e+03
# 50%    2894.500000    467.234018  6.658000e+03     2.639944  2.583347e+03
# 75%    4337.250000    980.647490  1.822638e+04     4.113016  4.762582e+03
# max    5782.000000  31466.324805  4.814334e+06    56.633370  3.086666e+06
#
#        mean_intensity  standard_deviation    smoothness      skewness  \
# count     5700.000000         5700.000000  5.700000e+03  5.700000e+03
# mean     32739.998756        18918.509163  1.000000e+00  1.136717e+08
# std        375.497536          107.701642  3.184057e-11  1.251622e+11
# min      30887.423873        18315.526662  1.000000e+00 -6.084929e+11
# 25%      32514.118976        18862.527581  1.000000e+00 -6.592992e+10
# 50%      32758.830631        18919.898278  1.000000e+00  8.976394e+08
# 75%      32963.472880        18975.360082  1.000000e+00  6.626634e+10
# max      34484.558125        19455.624403  1.000000e+00  6.646144e+11
#
#        correlation     contrast   uniformity  homogeneity       energy  \
# count  5700.000000  5700.000000  5700.000000  5700.000000  5700.000000
# mean      0.517923   405.436029     0.196819     0.449270     0.416811
# std       0.100541   106.173278     0.133754     0.143683     0.151960
# min       0.106935    68.602843     0.002550     0.102046     0.050501
# 25%       0.455528   329.482815     0.090453     0.340036     0.300753
# 50%       0.533856   408.948900     0.168198     0.443435     0.410120
# 75%       0.593590   485.913618     0.275302     0.551377     0.524692
# max       0.713186   671.470588     0.812420     0.906847     0.901343
#
#        dissimilarity  class_id
# count    5700.000000    5700.0
# mean       12.553969      -1.0
# std         3.280804       0.0
# min         2.123565      -1.0
# 25%        10.212198      -1.0
# 50%        12.678182      -1.0
# 75%        15.056238      -1.0
# max        20.527574      -1.0

# %%
print(f"Found {len(data_masses)} masses")
print(f"Found {len(small_fp)} false positives")
print(f"{round(100*len(data_masses)/(len(small_fp) + len(data_masses)), 1)}% of the whole data is masses.")
# Out:
# Found 83 masses
# Found 5700 false positives
# 1.4% of the whole data is masses.
