# %% [markdown]
# # Data analysis

# %%
import pandas as pd

# %%
# For this file we used Dice threshold 0.2, and the min area of a region of interest is 625
#data = pd.read_csv("feature-tables/train-data_1526149385.csv")

# For this file we used Dice threshold 0.2, and the min area of a region of interest is 2500
data = pd.read_csv("feature-tables/train-data_1526205815.csv")

data.describe()
# Out:
#        Unnamed: 0     perimeter          area  circularity             ac  \
# count  6376.00000   6376.000000  6.376000e+03  6376.000000    6376.000000
# mean   3187.50000    959.102949  2.467594e+04     4.006655    4145.178015
# std    1840.73699   1473.795891  9.103503e+04     3.468185   12230.479365
# min       0.00000    205.899495  2.500500e+03     1.299144     429.207875
# 25%    1593.75000    317.043415  3.606375e+03     2.133570    1574.466224
# 50%    3187.50000    459.870057  5.893750e+03     2.852777    2141.246859
# 75%    4781.25000    869.095453  1.419850e+04     4.367658    3593.721990
# max    6375.00000  21135.787131  4.221668e+06    36.685253  735442.086714
#
#        mean_intensity  standard_deviation    smoothness      skewness  \
# count     6376.000000         6376.000000  6.376000e+03  6.376000e+03
# mean     32870.082677        18914.703617  1.000000e+00 -1.557149e+08
# std        359.915100          110.771092  3.278071e-11  1.275335e+11
# min      31346.000000        18379.607729  1.000000e+00 -6.324181e+11
# 25%      32664.790847        18855.254570  1.000000e+00 -7.012823e+10
# 50%      32869.248871        18914.950634  1.000000e+00  9.464169e+08
# 75%      33088.076308        18975.497422  1.000000e+00  6.831841e+10
# max      34612.210145        19341.152371  1.000000e+00  6.652086e+11
#
#           class_id
# count  6376.000000
# mean     -0.965496
# std       0.260440
# min      -1.000000
# 25%      -1.000000
# 50%      -1.000000
# 75%      -1.000000
# max       1.000000

# %%
# data division into masses and not masses
data_masses = data[data["class_id"] == 1]

data_fp = data[data["class_id"] == -1]

print(f"Found {len(data_masses)} masses")
print(f"Found {len(data_fp)} false positives")
print(f"{round(100*len(data_masses)/len(data), 1)}% of the whole data is masses.")
# Out:
# Found 110 masses
# Found 6266 false positives
# 1.7% of the whole data is masses.

# %% [markdown]
# ## Mass analysis

# %%
data_masses.describe()
# Out:
#         Unnamed: 0     perimeter           area  circularity             ac  \
# count   110.000000    110.000000     110.000000   110.000000     110.000000
# mean   3196.690909   2431.353544  120165.563636     4.721779   23715.677413
# std    1864.260464   2372.089604  159359.434047     3.658016   25539.851312
# min      40.000000    279.899495    3723.000000     1.489771    2095.820299
# 25%    1596.000000    801.039104   21888.625000     2.368521    7133.268557
# 50%    3101.500000   1711.421353   63215.000000     3.434282   13366.839684
# 75%    4839.000000   2774.660727  131174.000000     5.636517   31546.023452
# max    6375.000000  14421.769885  869137.500000    19.043149  179625.857524
#
#        mean_intensity  standard_deviation    smoothness      skewness  \
# count      110.000000          110.000000  1.100000e+02  1.100000e+02
# mean     32809.351782        18916.646529  1.000000e+00 -1.109607e+09
# std        207.612684           48.741668  1.437222e-11  6.942918e+10
# min      32047.874420        18788.524484  1.000000e+00 -4.102694e+11
# 25%      32720.649025        18893.233072  1.000000e+00 -2.733217e+10
# 50%      32777.700885        18918.449475  1.000000e+00 -5.388598e+09
# 75%      32922.281529        18937.605267  1.000000e+00  1.990044e+10
# max      33743.957762        19127.628743  1.000000e+00  2.709865e+11
#
#        class_id
# count     110.0
# mean        1.0
# std         0.0
# min         1.0
# 25%         1.0
# 50%         1.0
# 75%         1.0
# max         1.0

# %%
data_masses[data_masses.area < 2500].count()
# Out:
# Unnamed: 0            0
# perimeter             0
# area                  0
# circularity           0
# ac                    0
# mean_intensity        0
# standard_deviation    0
# smoothness            0
# skewness              0
# class_id              0
# dtype: int64

# %%
from math import sqrt

print(f"Maximum square size for rejection {int(sqrt(data_masses.area.min()))}")
# Out:
# Maximum square size for rejection 61

# %% [markdown]
# ## False positive analysis

# %%
data_fp.describe()
# Out:
#         Unnamed: 0     perimeter          area  circularity             ac  \
# count  6266.000000   6266.000000  6.266000e+03  6266.000000    6266.000000
# mean   3187.338653    933.257503  2.299961e+04     3.994101    3801.616742
# std    1840.471585   1439.996378  8.847679e+04     3.463748   11576.684460
# min       0.000000    205.899495  2.500500e+03     1.299144     429.207875
# 25%    1594.250000    315.698484  3.583125e+03     2.129466    1564.306915
# 50%    3189.500000    453.183766  5.756250e+03     2.843405    2118.675268
# 75%    4779.750000    845.135298  1.352512e+04     4.353147    3466.144075
# max    6374.000000  21135.787131  4.221668e+06    36.685253  735442.086714
#
#        mean_intensity  standard_deviation    smoothness      skewness  \
# count     6266.000000         6266.000000  6.266000e+03  6.266000e+03
# mean     32871.148811        18914.669509  1.000000e+00 -1.389692e+08
# std        361.935759          111.553900  3.301268e-11  1.283218e+11
# min      31346.000000        18379.607729  1.000000e+00 -6.324181e+11
# 25%      32662.985270        18854.158374  1.000000e+00 -7.149751e+10
# 50%      32870.860055        18914.890300  1.000000e+00  1.042762e+09
# 75%      33092.795683        18976.424029  1.000000e+00  6.884514e+10
# max      34612.210145        19341.152371  1.000000e+00  6.652086e+11
#
#        class_id
# count    6266.0
# mean       -1.0
# std         0.0
# min        -1.0
# 25%        -1.0
# 50%        -1.0
# 75%        -1.0
# max        -1.0

# %%
small_fp = data_fp[data_fp.area > 2500]

small_fp.describe()
# Out:
#         Unnamed: 0     perimeter          area  circularity             ac  \
# count  6266.000000   6266.000000  6.266000e+03  6266.000000    6266.000000
# mean   3187.338653    933.257503  2.299961e+04     3.994101    3801.616742
# std    1840.471585   1439.996378  8.847679e+04     3.463748   11576.684460
# min       0.000000    205.899495  2.500500e+03     1.299144     429.207875
# 25%    1594.250000    315.698484  3.583125e+03     2.129466    1564.306915
# 50%    3189.500000    453.183766  5.756250e+03     2.843405    2118.675268
# 75%    4779.750000    845.135298  1.352512e+04     4.353147    3466.144075
# max    6374.000000  21135.787131  4.221668e+06    36.685253  735442.086714
#
#        mean_intensity  standard_deviation    smoothness      skewness  \
# count     6266.000000         6266.000000  6.266000e+03  6.266000e+03
# mean     32871.148811        18914.669509  1.000000e+00 -1.389692e+08
# std        361.935759          111.553900  3.301268e-11  1.283218e+11
# min      31346.000000        18379.607729  1.000000e+00 -6.324181e+11
# 25%      32662.985270        18854.158374  1.000000e+00 -7.149751e+10
# 50%      32870.860055        18914.890300  1.000000e+00  1.042762e+09
# 75%      33092.795683        18976.424029  1.000000e+00  6.884514e+10
# max      34612.210145        19341.152371  1.000000e+00  6.652086e+11
#
#        class_id
# count    6266.0
# mean       -1.0
# std         0.0
# min        -1.0
# 25%        -1.0
# 50%        -1.0
# 75%        -1.0
# max        -1.0

# %%
print(f"Found {len(data_masses)} masses")
print(f"Found {len(small_fp)} false positives")
print(f"{round(100*len(data_masses)/(len(small_fp) + len(data_masses)), 1)}% of the whole data is masses.")
# Out:
# Found 110 masses
# Found 6266 false positives
# 1.7% of the whole data is masses.
