# %%
from immas import preprocessing
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('../dataset/images/20586908_6c613a14b80a8591_MG_R_CC_ANON.tif',0)
img2 = preprocessing.clahe(img,2.0,(8,8))
plt.figure()
plt.imshow(img, cmap="gray")
plt.figure()
plt.imshow(img2, cmap='gray')
img2.dtype
# Out:
# dtype('uint8')
